# %%
import numpy as np
import pandas as pd
import os
import urllib
# %matplotlib inline

# %%
url = "https://covid19.who.int/WHO-COVID-19-global-data.csv"
file_path = os.path.join("data", "covid")

# %%
os.makedirs(file_path, exist_ok=True)
csv_path = os.path.join(file_path, "WHO-COVID-19-global-data.csv")
urllib.request.urlretrieve(url, csv_path)
# Out:
# ('data\\covid\\WHO-COVID-19-global-data.csv',
#  <http.client.HTTPMessage at 0x1b6ad834430>)

# %%
df = pd.read_csv(csv_path)

# %%
df
# Out:
#        Date_reported Country_code      Country WHO_region  New_cases  \
# 0         2020-01-03           AF  Afghanistan       EMRO          0
# 1         2020-01-04           AF  Afghanistan       EMRO          0
# 2         2020-01-05           AF  Afghanistan       EMRO          0
# 3         2020-01-06           AF  Afghanistan       EMRO          0
# 4         2020-01-07           AF  Afghanistan       EMRO          0
# ...              ...          ...          ...        ...        ...
# 124420    2021-06-06           ZW     Zimbabwe       AFRO         24
# 124421    2021-06-07           ZW     Zimbabwe       AFRO         21
# 124422    2021-06-08           ZW     Zimbabwe       AFRO         49
# 124423    2021-06-09           ZW     Zimbabwe       AFRO         83
# 124424    2021-06-10           ZW     Zimbabwe       AFRO        111
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 0                      0           0                  0
# ...

# %%
df_index = df.index
df_index
# Out:
# RangeIndex(start=0, stop=124425, step=1)

# %%
df_cols = df.columns
df_cols
# Out:
# Index(['Date_reported', 'Country_code', 'Country', 'WHO_region', 'New_cases',
#        'Cumulative_cases', 'New_deaths', 'Cumulative_deaths'],
#       dtype='object')

# %%
df_index.values
# Out:
# array([     0,      1,      2, ..., 124422, 124423, 124424], dtype=int64)

# %%
df.values
# Out:
# array([['2020-01-03', 'AF', 'Afghanistan', ..., 0, 0, 0],
#        ['2020-01-04', 'AF', 'Afghanistan', ..., 0, 0, 0],
#        ['2020-01-05', 'AF', 'Afghanistan', ..., 0, 0, 0],
#        ...,
#        ['2021-06-08', 'ZW', 'Zimbabwe', ..., 39238, 5, 1611],
#        ['2021-06-09', 'ZW', 'Zimbabwe', ..., 39321, 6, 1617],
#        ['2021-06-10', 'ZW', 'Zimbabwe', ..., 39432, 5, 1622]],
#       dtype=object)

# %%
df.dtypes
# Out:
# Date_reported        object
# Country_code         object
# Country              object
# WHO_region           object
# New_cases             int64
# Cumulative_cases      int64
# New_deaths            int64
# Cumulative_deaths     int64
# dtype: object

# %%
df.shape
# Out:
# (124425, 8)

# %%
df.head()
# Out:
#   Date_reported Country_code      Country WHO_region  New_cases  \
# 0    2020-01-03           AF  Afghanistan       EMRO          0
# 1    2020-01-04           AF  Afghanistan       EMRO          0
# 2    2020-01-05           AF  Afghanistan       EMRO          0
# 3    2020-01-06           AF  Afghanistan       EMRO          0
# 4    2020-01-07           AF  Afghanistan       EMRO          0
#
#    Cumulative_cases  New_deaths  Cumulative_deaths
# 0                 0           0                  0
# 1                 0           0                  0
# 2                 0           0                  0
# 3                 0           0                  0
# 4                 0           0                  0

# %%
df.tail()
# Out:
#        Date_reported Country_code   Country WHO_region  New_cases  \
# 124420    2021-06-06           ZW  Zimbabwe       AFRO         24
# 124421    2021-06-07           ZW  Zimbabwe       AFRO         21
# 124422    2021-06-08           ZW  Zimbabwe       AFRO         49
# 124423    2021-06-09           ZW  Zimbabwe       AFRO         83
# 124424    2021-06-10           ZW  Zimbabwe       AFRO        111
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 124420             39168           0               1605
# 124421             39189           1               1606
# 124422             39238           5               1611
# 124423             39321           6               1617
# 124424             39432           5               1622

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124425 entries, 0 to 124424
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Date_reported      124425 non-null  object
#  1   Country_code       123900 non-null  object
#  2   Country            124425 non-null  object
#  3   WHO_region         124425 non-null  object
#  4   New_cases          124425 non-null  int64
#  5   Cumulative_cases   124425 non-null  int64
#  6   New_deaths         124425 non-null  int64
#  7   Cumulative_deaths  124425 non-null  int64
# dtypes: int64(4), object(4)
# memory usage: 7.6+ MB

# %%
df.describe()
# Out:
#            New_cases  Cumulative_cases     New_deaths  Cumulative_deaths
# count  124425.000000      1.244250e+05  124425.000000      124425.000000
# mean     1398.931043      2.261024e+05      30.207434        5523.850802
# std      9631.255798      1.433812e+06     169.539375       29194.212375
# min    -32952.000000      0.000000e+00     -43.000000           0.000000
# 25%         0.000000      1.800000e+01       0.000000           0.000000
# 50%         7.000000      2.292000e+03       0.000000          38.000000
# 75%       288.000000      4.410700e+04       4.000000         733.000000
# max    414188.000000      3.307291e+07    6508.000000      592932.000000

# %%
df.Country
# Out:
# 0         Afghanistan
# 1         Afghanistan
# 2         Afghanistan
# 3         Afghanistan
# 4         Afghanistan
#              ...
# 124420       Zimbabwe
# 124421       Zimbabwe
# 124422       Zimbabwe
# 124423       Zimbabwe
# 124424       Zimbabwe
# Name: Country, Length: 124425, dtype: object

# %%
df.Country.unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Anguilla', 'Antigua and Barbuda', 'Argentina',
#        'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus',
#        'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
#        'Bolivia (Plurinational State of)', 'Bonaire',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei Darussalam', 'Bulgaria',
#        'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon',
#        'Canada', 'Cayman Islands', 'Central African Republic', 'Chad',
#        'Chile', 'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', 'Côte d’Ivoire', 'Croatia', 'Cuba', 'Curaçao',
#        'Cyprus', 'Czechia', "Democratic People's Republic of Korea",
#        'Democratic Republic of the Congo', 'Denmark', 'Djibouti',
# ...

# %%
len(df.Country.unique())
# Out:
# 237

# %% [markdown]
# #### Note
# ***
# Total unique locations are more than the total countries in the world.
# Some colonies, islands, sovereign states, etc. are being treated as unique locations(countries) by **WHO** to map the vector of the virus.

# %%
# df.loc[row_indexer, "column_indexer"]
df.loc[1:4, "Country"]
# Out:
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: Country, dtype: object

# %%
df.loc[1:8, ["Country", "New_cases"]]
# Out:
#        Country  New_cases
# 1  Afghanistan          0
# 2  Afghanistan          0
# 3  Afghanistan          0
# 4  Afghanistan          0
# 5  Afghanistan          0
# 6  Afghanistan          0
# 7  Afghanistan          0
# 8  Afghanistan          0

# %%
df.Country == "United States of America"
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 124420    False
# 124421    False
# 124422    False
# 124423    False
# 124424    False
# Name: Country, Length: 124425, dtype: bool

# %%
df[df.Country == "United States of America"]
# Out:
#        Date_reported Country_code                   Country WHO_region  \
# 118650    2020-01-03           US  United States of America       AMRO
# 118651    2020-01-04           US  United States of America       AMRO
# 118652    2020-01-05           US  United States of America       AMRO
# 118653    2020-01-06           US  United States of America       AMRO
# 118654    2020-01-07           US  United States of America       AMRO
# ...              ...          ...                       ...        ...
# 119170    2021-06-06           US  United States of America       AMRO
# 119171    2021-06-07           US  United States of America       AMRO
# 119172    2021-06-08           US  United States of America       AMRO
# 119173    2021-06-09           US  United States of America       AMRO
# 119174    2021-06-10           US  United States of America       AMRO
#
#         New_cases  Cumulative_cases  New_deaths  Cumulative_deaths
# ...

# %%
df[df.Country == "Bangladesh"]
# Out:
#      Date_reported Country_code     Country WHO_region  New_cases  \
# 8400    2020-01-03           BD  Bangladesh      SEARO          0
# 8401    2020-01-04           BD  Bangladesh      SEARO          0
# 8402    2020-01-05           BD  Bangladesh      SEARO          0
# 8403    2020-01-06           BD  Bangladesh      SEARO          0
# 8404    2020-01-07           BD  Bangladesh      SEARO          0
# ...            ...          ...         ...        ...        ...
# 8920    2021-06-06           BD  Bangladesh      SEARO       1447
# 8921    2021-06-07           BD  Bangladesh      SEARO       1676
# 8922    2021-06-08           BD  Bangladesh      SEARO       1970
# 8923    2021-06-09           BD  Bangladesh      SEARO       2322
# 8924    2021-06-10           BD  Bangladesh      SEARO       2537
#
#       Cumulative_cases  New_deaths  Cumulative_deaths
# 8400                 0           0                  0
# 8401                 0           0                  0
# ...

# %%
df[df.New_deaths > 1000]
# Out:
#        Date_reported Country_code                           Country  \
# 4474      2020-10-03           AR                         Argentina
# 12849     2020-09-08           BO  Bolivia (Plurinational State of)
# 14839     2020-05-21           BR                            Brazil
# 14841     2020-05-23           BR                            Brazil
# 14842     2020-05-24           BR                            Brazil
# ...              ...          ...                               ...
# 119093    2021-03-21           US          United States of America
# 119098    2021-03-26           US          United States of America
# 119099    2021-03-27           US          United States of America
# 119100    2021-03-28           US          United States of America
# 119161    2021-05-28           US          United States of America
#
#        WHO_region  New_cases  Cumulative_cases  New_deaths  Cumulative_deaths
# ...

# %%
df.loc[df.New_deaths > 1000, ["New_deaths", "Country"]]
# Out:
#         New_deaths                           Country
# 4474          3351                         Argentina
# 12849         1610  Bolivia (Plurinational State of)
# 14839         1179                            Brazil
# 14841         1188                            Brazil
# 14842         1001                            Brazil
# ...            ...                               ...
# 119093        1359          United States of America
# 119098        1091          United States of America
# 119099        1237          United States of America
# 119100        1170          United States of America
# 119161        1120          United States of America
#
# [609 rows x 2 columns]

# %%
df.loc[(df.New_deaths > 1000) & (df.Country_code == 'US'), ["New_cases", "Country"]]
# Out:
#         New_cases                   Country
# 118743      35131  United States of America
# 118744      30593  United States of America
# 118745      25511  United States of America
# 118746      42604  United States of America
# 118748      31714  United States of America
# ...           ...                       ...
# 119093      61405  United States of America
# 119098      65751  United States of America
# 119099      67796  United States of America
# 119100      71388  United States of America
# 119161      24462  United States of America
#
# [215 rows x 2 columns]

# %%
df.loc[(df.New_deaths > 1000) & (df.Country_code == 'US'), ['Date_reported', 'Country', 'New_deaths', 'Cumulative_deaths']]
# Out:
#        Date_reported                   Country  New_deaths  Cumulative_deaths
# 118743    2020-04-05  United States of America        1067               6856
# 118744    2020-04-06  United States of America        1157               8013
# 118745    2020-04-07  United States of America        1364               9377
# 118746    2020-04-08  United States of America        3243              12620
# 118748    2020-04-10  United States of America        1958              15252
# ...              ...                       ...         ...                ...
# 119093    2021-03-21  United States of America        1359             539915
# 119098    2021-03-26  United States of America        1091             543855
# 119099    2021-03-27  United States of America        1237             545092
# 119100    2021-03-28  United States of America        1170             546262
# 119161    2021-05-28  United States of America        1120             586890
#
# [215 rows x 4 columns]

# %%
df.loc[(df.Country_code == 'US'), ["New_cases"]].max()
# Out:
# New_cases    312247
# dtype: int64

# %%
df.loc[(df.Country_code == 'US'), ["New_cases"]].min()
# Out:
# New_cases    0
# dtype: int64

# %%
df.loc[(df.Country_code == 'US'), ["New_cases"]].sum()
# Out:
# New_cases    33072912
# dtype: int64

# %%
df.loc[(df.Country_code == 'US'), ["Cumulative_cases"]].max()
# Out:
# Cumulative_cases    33072912
# dtype: int64

# %%
df.New_deaths.idxmax()
# Out:
# 118755

# %%
df.loc[df.New_deaths.idxmax(), ['Date_reported', 'Country', 'New_cases', 'New_deaths']]
# Out:
# Date_reported                  2020-04-17
# Country          United States of America
# New_cases                           27172
# New_deaths                           6508
# Name: 118755, dtype: object

# %%
df[df.New_deaths < 0]
# Out:
#        Date_reported Country_code                Country WHO_region  \
# 1264      2020-08-04           DZ                Algeria       AFRO
# 2901      2020-10-05           AO                 Angola       AFRO
# 7590      2020-08-30           BS                Bahamas       AMRO
# 7807      2021-04-04           BS                Bahamas       AMRO
# 16992     2020-07-13           BF           Burkina Faso       AFRO
# 23783     2020-06-09           CG                  Congo       AFRO
# 26475     2020-08-15           CU                   Cuba       AMRO
# 28009     2020-07-05           CZ                Czechia       EURO
# 28010     2020-07-06           CZ                Czechia       EURO
# 33962     2020-12-30           ER                Eritrea       AFRO
# 34047     2021-03-25           ER                Eritrea       AFRO
# 34890     2020-08-30           SZ               Eswatini       AFRO
# 35097     2021-03-25           SZ               Eswatini       AFRO
# ...

# %% [markdown]
# #### Drop incorrent data
# Probably wrong data. Or, child births increasing total population and deaths were being calculated against last recorded total population.
